# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

A=np.array([[1,2,3],[4,5,6]])
B=np.array([[7,8],[9,10],[11,12]])
C=A @ B
print("Matrix C: \n", C)

x=np.arange(0,10)
y=x**2
plt.plot(x,y)
plt.title("y=x^2")
plt.show()
# Out:
# Matrix C:
#  [[ 58  64]
#  [139 154]]
